# %%
from webcolors import (
    CSS3_HEX_TO_NAMES,
    hex_to_rgb,
)
from scipy.spatial import KDTree

# %%
def get_all_color_names():
    css3_db = CSS3_HEX_TO_NAMES
    color_names = []
    color_rgb_values = []
    for color_hex, color_name in css3_db.items():
        color_names.append(color_name)
        color_rgb_values.append(hex_to_rgb(color_hex))
    return color_names, color_rgb_values

# %%
COLOR_NAMES, COLOR_RGB_VALUES = get_all_color_names()
KDT_DB = KDTree(COLOR_RGB_VALUES)

# %%
print(COLOR_NAMES)
# Out:
# ['aliceblue', 'antiquewhite', 'cyan', 'aquamarine', 'azure', 'beige', 'bisque', 'black', 'blanchedalmond', 'blue', 'blueviolet', 'brown', 'burlywood', 'cadetblue', 'chartreuse', 'chocolate', 'coral', 'cornflowerblue', 'cornsilk', 'crimson', 'darkblue', 'darkcyan', 'darkgoldenrod', 'darkgray', 'darkgreen', 'darkkhaki', 'darkmagenta', 'darkolivegreen', 'darkorange', 'darkorchid', 'darkred', 'darksalmon', 'darkseagreen', 'darkslateblue', 'darkslategray', 'darkturquoise', 'darkviolet', 'deeppink', 'deepskyblue', 'dimgray', 'dodgerblue', 'firebrick', 'floralwhite', 'forestgreen', 'magenta', 'gainsboro', 'ghostwhite', 'gold', 'goldenrod', 'gray', 'green', 'greenyellow', 'honeydew', 'hotpink', 'indianred', 'indigo', 'ivory', 'khaki', 'lavender', 'lavenderblush', 'lawngreen', 'lemonchiffon', 'lightblue', 'lightcoral', 'lightcyan', 'lightgoldenrodyellow', 'lightgray', 'lightgreen', 'lightpink', 'lightsalmon', 'lightseagreen', 'lightskyblue', 'lightslategray', 'lightsteelblue', 'lightyellow', 'lime', 'limegreen', 'linen', 'maroon', 'mediumaquamarine', 'mediumblue', 'mediumorchid', 'mediumpurple', 'mediumseagreen', 'mediumslateblue', 'mediumspringgreen', 'mediumturquoise', 'mediumvioletred', 'midnightblue', 'mintcream', 'mistyrose', 'moccasin', 'navajowhite', 'navy', 'oldlace', 'olive', 'olivedrab', 'orange', 'orangered', 'orchid', 'palegoldenrod', 'palegreen', 'paleturquoise', 'palevioletred', 'papayawhip', 'peachpuff', 'peru', 'pink', 'plum', 'powderblue', 'purple', 'red', 'rosybrown', 'royalblue', 'saddlebrown', 'salmon', 'sandybrown', 'seagreen', 'seashell', 'sienna', 'silver', 'skyblue', 'slateblue', 'slategray', 'snow', 'springgreen', 'steelblue', 'tan', 'teal', 'thistle', 'tomato', 'turquoise', 'violet', 'wheat', 'white', 'whitesmoke', 'yellow', 'yellowgreen']

# %%
print(COLOR_RGB_VALUES)
# Out:
# [IntegerRGB(red=240, green=248, blue=255), IntegerRGB(red=250, green=235, blue=215), IntegerRGB(red=0, green=255, blue=255), IntegerRGB(red=127, green=255, blue=212), IntegerRGB(red=240, green=255, blue=255), IntegerRGB(red=245, green=245, blue=220), IntegerRGB(red=255, green=228, blue=196), IntegerRGB(red=0, green=0, blue=0), IntegerRGB(red=255, green=235, blue=205), IntegerRGB(red=0, green=0, blue=255), IntegerRGB(red=138, green=43, blue=226), IntegerRGB(red=165, green=42, blue=42), IntegerRGB(red=222, green=184, blue=135), IntegerRGB(red=95, green=158, blue=160), IntegerRGB(red=127, green=255, blue=0), IntegerRGB(red=210, green=105, blue=30), IntegerRGB(red=255, green=127, blue=80), IntegerRGB(red=100, green=149, blue=237), IntegerRGB(red=255, green=248, blue=220), IntegerRGB(red=220, green=20, blue=60), IntegerRGB(red=0, green=0, blue=139), IntegerRGB(red=0, green=139, blue=139), IntegerRGB(red=184, green=134, blue=11), IntegerRGB(red=169, green=169, blue=169), IntegerRGB(red=0, green=100, blue=0), IntegerRGB(red=189, green=183, blue=107), IntegerRGB(red=139, green=0, blue=139), IntegerRGB(red=85, green=107, blue=47), IntegerRGB(red=255, green=140, blue=0), IntegerRGB(red=153, green=50, blue=204), IntegerRGB(red=139, green=0, blue=0), IntegerRGB(red=233, green=150, blue=122), IntegerRGB(red=143, green=188, blue=143), IntegerRGB(red=72, green=61, blue=139), IntegerRGB(red=47, green=79, blue=79), IntegerRGB(red=0, green=206, blue=209), IntegerRGB(red=148, green=0, blue=211), IntegerRGB(red=255, green=20, blue=147), IntegerRGB(red=0, green=191, blue=255), IntegerRGB(red=105, green=105, blue=105), IntegerRGB(red=30, green=144, blue=255), IntegerRGB(red=178, green=34, blue=34), IntegerRGB(red=255, green=250, blue=240), IntegerRGB(red=34, green=139, blue=34), IntegerRGB(red=255, green=0, blue=255), IntegerRGB(red=220, green=220, blue=220), IntegerRGB(red=248, green=248, blue=255), IntegerRGB(red=255, green=215, blue=0), IntegerRGB(red=218, green=165, blue=32), IntegerRGB(red=128, green=128, blue=128), IntegerRGB(red=0, green=128, blue=0), IntegerRGB(red=173, green=255, blue=47), IntegerRGB(red=240, green=255, blue=240), IntegerRGB(red=255, green=105, blue=180), IntegerRGB(red=205, green=92, blue=92), IntegerRGB(red=75, green=0, blue=130), IntegerRGB(red=255, green=255, blue=240), IntegerRGB(red=240, green=230, blue=140), IntegerRGB(red=230, green=230, blue=250), IntegerRGB(red=255, green=240, blue=245), IntegerRGB(red=124, green=252, blue=0), IntegerRGB(red=255, green=250, blue=205), IntegerRGB(red=173, green=216, blue=230), IntegerRGB(red=240, green=128, blue=128), IntegerRGB(red=224, green=255, blue=255), IntegerRGB(red=250, green=250, blue=210), IntegerRGB(red=211, green=211, blue=211), IntegerRGB(red=144, green=238, blue=144), IntegerRGB(red=255, green=182, blue=193), IntegerRGB(red=255, green=160, blue=122), IntegerRGB(red=32, green=178, blue=170), IntegerRGB(red=135, green=206, blue=250), IntegerRGB(red=119, green=136, blue=153), IntegerRGB(red=176, green=196, blue=222), IntegerRGB(red=255, green=255, blue=224), IntegerRGB(red=0, green=255, blue=0), IntegerRGB(red=50, green=205, blue=50), IntegerRGB(red=250, green=240, blue=230), IntegerRGB(red=128, green=0, blue=0), IntegerRGB(red=102, green=205, blue=170), IntegerRGB(red=0, green=0, blue=205), IntegerRGB(red=186, green=85, blue=211), IntegerRGB(red=147, green=112, blue=219), IntegerRGB(red=60, green=179, blue=113), IntegerRGB(red=123, green=104, blue=238), IntegerRGB(red=0, green=250, blue=154), IntegerRGB(red=72, green=209, blue=204), IntegerRGB(red=199, green=21, blue=133), IntegerRGB(red=25, green=25, blue=112), IntegerRGB(red=245, green=255, blue=250), IntegerRGB(red=255, green=228, blue=225), IntegerRGB(red=255, green=228, blue=181), IntegerRGB(red=255, green=222, blue=173), IntegerRGB(red=0, green=0, blue=128), IntegerRGB(red=253, green=245, blue=230), IntegerRGB(red=128, green=128, blue=0), IntegerRGB(red=107, green=142, blue=35), IntegerRGB(red=255, green=165, bl ...

# %%
import math

def rgb_to_simple_color(rgb):
    """
    Maps an RGB color to a simple color (red, orange, yellow, green, blue, purple, pink, grey, black, white).

    :param rgb: A tuple (R, G, B) representing the RGB values.
    :return: A string representing the simple color.
    """
    # Define RGB values for simple colors
    simple_colors = {
        "red": (255, 0, 0),
        "orange": (255, 165, 0),
        "yellow": (255, 255, 0),
        "green": (0, 128, 0),
        "blue": (0, 0, 255),
        "purple": (128, 0, 128),
        "pink": (255, 192, 203),
        "grey": (128, 128, 128),
        "black": (0, 0, 0),
        "white": (255, 255, 255)
    }

    def color_distance(c1, c2):
        """Calculate the Euclidean distance between two colors."""
        return math.sqrt(sum([(a - b) ** 2 for a, b in zip(c1, c2)]))

    # Check for special cases of black, white, and grey
    if all(x < 50 for x in rgb):  # Arbitrarily chosen threshold for black
        return "black"
    if all(x > 200 for x in rgb):  # Arbitrarily chosen threshold for white
        return "white"
    if max(rgb) - min(rgb) < 30:  # Threshold for grey, based on low variance in RGB values
        return "grey"

    # Find the closest simple color
    closest_color = min(simple_colors, key=lambda color: color_distance(rgb, simple_colors[color]))
    return closest_color

# Map each color to a simple color
simple_color_mapping = {color: (rgb, rgb_to_simple_color(rgb)) for color, rgb in zip(COLOR_NAMES, COLOR_RGB_VALUES)}
simple_color_mapping
# Out:
# {'aliceblue': (IntegerRGB(red=240, green=248, blue=255), 'white'),
#  'antiquewhite': (IntegerRGB(red=250, green=235, blue=215), 'white'),
#  'cyan': (IntegerRGB(red=0, green=255, blue=255), 'grey'),
#  'aquamarine': (IntegerRGB(red=127, green=255, blue=212), 'white'),
#  'azure': (IntegerRGB(red=240, green=255, blue=255), 'white'),
#  'beige': (IntegerRGB(red=245, green=245, blue=220), 'white'),
#  'bisque': (IntegerRGB(red=255, green=228, blue=196), 'pink'),
#  'black': (IntegerRGB(red=0, green=0, blue=0), 'black'),
#  'blanchedalmond': (IntegerRGB(red=255, green=235, blue=205), 'white'),
#  'blue': (IntegerRGB(red=0, green=0, blue=255), 'blue'),
#  'blueviolet': (IntegerRGB(red=138, green=43, blue=226), 'purple'),
#  'brown': (IntegerRGB(red=165, green=42, blue=42), 'purple'),
#  'burlywood': (IntegerRGB(red=222, green=184, blue=135), 'pink'),
#  'cadetblue': (IntegerRGB(red=95, green=158, blue=160), 'grey'),
#  'chartreuse': (IntegerRGB(red=127, green=255, blue=0), 'yellow'),
#  'chocolate': (IntegerRGB(red=210, green=105, blue=30), 'orange'),
#  'coral': (IntegerRGB(red=255, green=127, blue=80), 'orange'),
#  'cornflowerblue': (IntegerRGB(red=100, green=149, blue=237), 'grey'),
#  'cornsilk': (IntegerRGB(red=255, green=248, blue=220), 'white'),
#  'crimson': (IntegerRGB(red=220, green=20, blue=60), 'red'),
#  'darkblue': (IntegerRGB(red=0, green=0, blue=139), 'blue'),
#  'darkcyan': (IntegerRGB(red=0, green=139, blue=139), 'grey'),
#  'darkgoldenrod': (IntegerRGB(red=184, green=134, blue=11), 'orange'),
#  'darkgray': (IntegerRGB(red=169, green=169, blue=169), 'grey'),
#  'darkgreen': (IntegerRGB(red=0, green=100, blue=0), 'green'),
#  'darkkhaki': (IntegerRGB(red=189, green=183, blue=107), 'grey'),
#  'darkmagenta': (IntegerRGB(red=139, green=0, blue=139), 'purple'),
#  'darkolivegreen': (IntegerRGB(red=85, green=107, blue=47), 'grey'),
#  'darkorange': (IntegerRGB(red=255, green=140, blue=0), 'orange'),
#  'darkorchid': (IntegerRGB(red=153, green=50, blue=204), 'purple'),
#  'darkred': (IntegerRGB(red=139, green=0, blue=0), 'red'),
#  'darksalmon': (IntegerRGB(red=233, green=150, blue=122), 'pink'),
#  'darkseagreen': (IntegerRGB(red=143, green=188, blue=143), 'grey'),
#  'darkslateblue': (IntegerRGB(red=72, green=61, blue=139), 'purple'),
#  'darkslategray': (IntegerRGB(red=47, green=79, blue=79), 'green'),
#  'darkturquoise': (IntegerRGB(red=0, green=206, blue=209), 'grey'),
#  'darkviolet': (IntegerRGB(red=148, green=0, blue=211), 'purple'),
#  'deeppink': (IntegerRGB(red=255, green=20, blue=147), 'purple'),
#  'deepskyblue': (IntegerRGB(red=0, green=191, blue=255), 'blue'),
#  'dimgray': (IntegerRGB(red=105, green=105, blue=105), 'grey'),
#  'dodgerblue': (IntegerRGB(red=30, green=144, blue=255), 'blue'),
#  'firebrick': (IntegerRGB(red=178, green=34, blue=34), 'red'),
#  'floralwhite': (IntegerRGB(red=255, green=250, blue=240), 'white'),
#  'forestgreen': (IntegerRGB(red=34, green=139, blue=34), 'green'),
#  'magenta': (IntegerRGB(red=255, green=0, blue=255), 'purple'),
#  'gainsboro': (IntegerRGB(red=220, green=220, blue=220), 'white'),
#  'ghostwhite': (IntegerRGB(red=248, green=248, blue=255), 'white'),
#  'gold': (IntegerRGB(red=255, green=215, blue=0), 'yellow'),
#  'goldenrod': (IntegerRGB(red=218, green=165, blue=32), 'orange'),
#  'gray': (IntegerRGB(red=128, green=128, blue=128), 'grey'),
#  'green': (IntegerRGB(red=0, green=128, blue=0), 'green'),
#  'greenyellow': (IntegerRGB(red=173, green=255, blue=47), 'yellow'),
#  'honeydew': (IntegerRGB(red=240, green=255, blue=240), 'white'),
#  'hotpink': (IntegerRGB(red=255, green=105, blue=180), 'pink'),
#  'indianred': (IntegerRGB(red=205, green=92, blue=92), 'grey'),
#  'indigo': (IntegerRGB(red=75, green=0, blue=130), 'purple'),
#  'ivory': (IntegerRGB(red=255, green=255, blue=240), 'white'),
#  'khaki': (IntegerRGB(red=240, green=230, blue=140), 'pink'),
#  'lavender': (IntegerRGB(red=230, green=230, blue=250), 'white'),
#  'lavenderblush': (IntegerRGB(red=255, green=240, blue=245), 'white'),
#  'lawngreen': (IntegerRGB(red=124, green=252, blue=0), 'yellow'),
#  'lemonchiffon': (IntegerRGB(red=255, green=250, blue=205), 'white'),
#  'lightblue': (IntegerRGB(red=173, green=216, blue=230), 'pink'),
#  'lightcoral': (IntegerRGB(red=240, green=128, blue=128), 'pink'),
#  'lightcyan': (IntegerRGB(red=224, green=255, blue=255), 'white'),
#  'lightgoldenrodyellow': (IntegerRGB(red=250, green=250, blue=210), 'white'),
#  'lightgray': (IntegerRGB(red=211, green=211, blue=211), 'white'),
#  'lightgreen': (IntegerRGB(red=144, green=238, blue=144), 'grey'),
#  'lightpink': (IntegerRGB(red=255, green=182, blue=193), 'pink'),
#  'lightsalmon': (IntegerRGB(red=255, green=160, blue=122), 'pink'),
#  'lightseagreen': (IntegerRGB(red=32, green=178, blue=170), 'grey'),
#  'lightskyblue': (IntegerRGB(red=135, green=206, blue=250), 'pink'),
#  'lightslategray': (IntegerRGB(red=119, green=136, blue=153), 'grey'),
#  'lightsteelblue': (IntegerRGB(red=176, green=196, blue=222), 'pink'),
#  'lightyellow': (IntegerRGB(red=255, green=255, blue=224), 'white'),
#  'lime': (IntegerRGB(red=0, green=255, blue=0), 'green'),
#  'limegreen': (IntegerRGB(red=50, green=205, blue=50), 'green'),
#  'linen': (IntegerRGB(red=250, green=240, blue=230), 'white'),
#  'maroon': (IntegerRGB(red=128, green=0, blue=0), 'red'),
#  'mediumaquamarine': (IntegerRGB(red=102, green=205, blue=170), 'grey'),
#  'mediumblue': (IntegerRGB(red=0, green=0, blue=205), 'blue'),
#  'mediumorchid': (IntegerRGB(red=186, green=85, blue=211), 'grey'),
#  'mediumpurple': (IntegerRGB(red=147, green=112, blue=219), 'grey'),
#  'mediumseagreen': (IntegerRGB(red=60, green=179, blue=113), 'grey'),
#  'mediumslateblue': (IntegerRGB(red=123, green=104, blue=238), 'grey'),
#  'mediumspringgreen': (IntegerRGB(red=0, green=250, blue=154), 'grey'),
#  'mediumturquoise': (IntegerRGB(red=72, green=209, blue=204), 'grey'),
#  'mediumvioletred': (IntegerRGB(red=199, green=21, blue=133), 'purple'),
#  'midnightblue': (IntegerRGB(red=25, green=25, blue=112), 'purple'),
#  'mintcream': (IntegerRGB(red=245, green=255, blue=250), 'white'),
#  'mistyrose': (IntegerRGB(red=255, green=228, blue=225), 'white'),
#  'moccasin': (IntegerRGB(red=255, green=228, blue=181), 'pink'),
#  'navajowhite': (IntegerRGB(red=255, green=222, blue=173), 'pink'),
#  'navy': (IntegerRGB(red=0, green=0, blue=128), 'blue'),
#  'oldlace': (IntegerRGB(red=253, green=245, blue=230), 'white'),
#  'olive': (IntegerRGB(red=128, green=128, blue=0), 'green'),
#  'olivedrab': (IntegerRGB(red=107, green=142, blue=35), 'grey'),
#  'orange': (IntegerRGB(red=255, green=165, blue=0), 'orange'),
#  'orangered': (IntegerRGB(red=255, green=69, blue=0), 'red'),
#  'orchid': (IntegerRGB(red=218, green=112, blue=214), 'pink'),
#  'palegoldenrod': (IntegerRGB(red=238, green=232, blue=170), 'pink'),
#  'palegreen': (IntegerRGB(red=152, green=251, blue=152), 'grey'),
#  'paleturquoise': (IntegerRGB(red=175, green=238, blue=238), 'white'),
#  'palevioletred': (IntegerRGB(red=219, green=112, blue=147), 'grey'),
#  'papayawhip': (IntegerRGB(red=255, green=239, blue=213), 'white'),
#  'peachpuff': (IntegerRGB(red=255, green=218, blue=185), 'pink'),
#  'peru': (IntegerRGB(red=205, green=133, blue=63), 'orange'),
#  'pink': (IntegerRGB(red=255, green=192, blue=203), 'pink'),
#  'plum': (IntegerRGB(red=221, green=160, blue=221), 'pink'),
#  'powderblue': (IntegerRGB(red=176, green=224, blue=230), 'white'),
#  'purple': (IntegerRGB(red=128, green=0, blue=128), 'purple'),
#  'red': (IntegerRGB(red=255, green=0, blue=0), 'red'),
#  'rosybrown': (IntegerRGB(red=188, green=143, blue=143), 'grey'),
#  'royalblue': (IntegerRGB(red=65, green=105, blue=225), 'grey'),
#  'saddlebrown': (IntegerRGB(red=139, green=69, blue=19), 'grey'),
#  'salmon': (IntegerRGB(red=250, green=128, blue=114), 'pink'),
#  'sandybrown': (IntegerRGB(red=244, green=164, blue=96), 'orange'),
#  'seagreen': (IntegerRGB(red=46, green=139, blue=87), 'grey'),
#  'seashell': (IntegerRGB(red=255, green=245, blue=238), 'white'),
#  'sienna': (IntegerRGB(red=160, green=82, blue=45), 'grey'),
#  'silver': (IntegerRGB(red=192, green=192, blue=192), 'grey'),
#  'skyblue': (IntegerRGB(red=135, green=206, blue=235), 'pink'),
#  'slateblue': (IntegerRGB(red=106, green=90, blue=205), 'grey'),
#  'slategray': (IntegerRGB(red=112, green=128, blue=144), 'grey'),
#  'snow': (IntegerRGB(red=255, green=250, blue=250), 'white'),
#  'springgreen': (IntegerRGB(red=0, green=255, blue=127), 'green'),
#  'steelblue': (IntegerRGB(red=70, green=130, blue=180), 'grey'),
#  'tan': (IntegerRGB(red=210, green=180, blue=140), 'pink'),
#  'teal': (IntegerRGB(red=0, green=128, blue=128), 'green'),
#  'thistle': (IntegerRGB(red=216, green=191, blue=216), 'grey'),
#  'tomato': (IntegerRGB(red=255, green=99, blue=71), 'orange'),
#  'turquoise': (IntegerRGB(red=64, green=224, blue=208), 'grey'),
#  'violet': (IntegerRGB(red=238, green=130, blue=238), 'pink'),
#  'wheat': (IntegerRGB(red=245, green=222, blue=179), 'pink'),
#  'white': (IntegerRGB(red=255, green=255, blue=255), 'white'),
#  'whitesmoke': (IntegerRGB(red=245, green=245, blue=245), 'white'),
#  'yellow': (IntegerRGB(red=255, green=255, blue=0), 'yellow'),
#  'yellowgreen': (IntegerRGB(red=154, green=205, blue=50), 'grey')}

# %%
complex_to_simple_color = {
    'aliceblue': 'white',
    'antiquewhite': 'white',
    'cyan': 'blue',
    'aquamarine': 'green',
    'azure': 'white',
    'beige': 'white',
    'bisque': 'white',
    'black': 'black',
    'blanchedalmond': 'white',
    'blue': 'blue',
    'blueviolet': 'purple',
    'brown': 'red',
    'burlywood': 'orange',
    'cadetblue': 'blue',
    'chartreuse': 'green',
    'chocolate': 'orange',
    'coral': 'orange',
    'cornflowerblue': 'blue',
    'cornsilk': 'white',
    'crimson': 'red',
    'darkblue': 'blue',
    'darkcyan': 'blue',
    'darkgoldenrod': 'yellow',
    'darkgray': 'grey',
    'darkgreen': 'green',
    'darkkhaki': 'yellow',
    'darkmagenta': 'purple',
    'darkolivegreen': 'green',
    'darkorange': 'orange',
    'darkorchid': 'purple',
    'darkred': 'red',
    'darksalmon': 'orange',
    'darkseagreen': 'green',
    'darkslateblue': 'purple',
    'darkslategray': 'blue',
    'darkturquoise': 'blue',
    'darkviolet': 'purple',
    'deeppink': 'pink',
    'deepskyblue': 'blue',
    'dimgray': 'grey',
    'dodgerblue': 'blue',
    'firebrick': 'red',
    'floralwhite': 'white',
    'forestgreen': 'green',
    'magenta': 'pink',
    'gainsboro': 'white',
    'ghostwhite': 'white',
    'gold': 'yellow',
    'goldenrod': 'yellow',
    'gray': 'grey',
    'green': 'green',
    'greenyellow': 'green',
    'honeydew': 'white',
    'hotpink': 'pink',
    'indianred': 'pink',
    'indigo': 'purple',
    'ivory': 'white',
    'khaki': 'yellow',
    'lavender': 'white',
    'lavenderblush': 'white',
    'lawngreen': 'green',
    'lemonchiffon': 'white',
    'lightblue': 'blue',
    'lightcoral': 'pink',
    'lightcyan': 'white',
    'lightgoldenrodyellow': 'white',
    'lightgray': 'grey',
    'lightgreen': 'green',
    'lightpink': 'pink',
    'lightsalmon': 'orange',
    'lightseagreen': 'blue',
    'lightskyblue': 'blue',
    'lightslategray': 'grey',
    'lightsteelblue': 'blue',
    'lightyellow': 'white',
    'lime': 'green',
    'limegreen': 'green',
    'linen': 'white',
    'maroon': 'red',
    'mediumaquamarine': 'green',
    'mediumblue': 'blue',
    'mediumorchid': 'purple',
    'mediumpurple': 'purple',
    'mediumseagreen': 'green',
    'mediumslateblue': 'purple',
    'mediumspringgreen': 'green',
    'mediumturquoise': 'blue',
    'mediumvioletred': 'pink',
    'midnightblue': 'blue',
    'mintcream': 'white',
    'mistyrose': 'white',
    'moccasin': 'yellow',
    'navajowhite': 'yellow',
    'navy': 'blue',
    'oldlace': 'white',
    'olive': 'green',
    'olivedrab': 'green',
    'orange': 'orange',
    'orangered': 'orange',
    'orchid': 'purple',
    'palegoldenrod': 'yellow',
    'palegreen': 'green',
    'paleturquoise': 'blue',
    'palevioletred': 'pink',
    'papayawhip': 'white',
    'peachpuff':'orange',
    'peru': 'orange',
    'pink': 'pink',
    'plum': 'purple',
    'powderblue': 'blue',
    'purple': 'purple',
    'red': 'red',
    'rosybrown': 'pink',
    'royalblue': 'blue',
    'saddlebrown': 'orange',
    'salmon': 'pink',
    'sandybrown': 'orange',
    'seagreen': 'green',
    'seashell': 'white',
    'sienna': 'orange',
    'silver': 'grey',
    'skyblue': 'blue',
    'slateblue': 'purple',
    'slategray': 'gray',
    'snow': 'white',
    'springgreen': 'green',
    'steelblue': 'blue',
    'tan': 'orange',
    'teal': 'blue',
    'thistle': 'pink',
    'tomato': 'orange',
    'turquoise': 'blue',
    'violet': 'pink',
    'wheat': 'yellow',
    'white': 'white',
    'whitesmoke': 'white',
    'yellow': 'yellow',
    'yellowgreen': 'green'
}
